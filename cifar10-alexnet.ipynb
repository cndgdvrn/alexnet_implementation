# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import cifar10

# load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()


train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# defining of AlexNet
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(filters=96, kernel_size=(11,11), strides=(4,4), activation='relu', padding='same', input_shape=(32,32,3)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same'),
    
    tf.keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same'),
    
    tf.keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same'),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=4096, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(units=4096, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(units=10, activation='softmax')
])

# compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# train model
model.fit(train_images, train_labels, epochs=10, batch_size=128, validation_data=(test_images, test_labels))

tf.keras.models.save_model(model, 'my_model.h5')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step
# Epoch 1/10
# 391/391 [==============================] - 544s 1s/step - loss: 1.7666 - accuracy: 0.3604 - val_loss: 1.6659 - val_accuracy: 0.4121
# Epoch 2/10
# 391/391 [==============================] - 538s 1s/step - loss: 1.4275 - accuracy: 0.4943 - val_loss: 1.6293 - val_accuracy: 0.4199
# Epoch 3/10
# 391/391 [==============================] - 527s 1s/step - loss: 1.3059 - accuracy: 0.5451 - val_loss: 1.7703 - val_accuracy: 0.4217
# Epoch 4/10
# 391/391 [==============================] - 533s 1s/step - loss: 1.2018 - accuracy: 0.5800 - val_loss: 1.3178 - val_accuracy: 0.5420
# Epoch 5/10
# 391/391 [==============================] - 530s 1s/step - loss: 1.1179 - accuracy: 0.6136 - val_loss: 1.7339 - val_accuracy: 0.4756
# Epoch 6/10
# 391/391 [==============================] - 538s 1s/step - loss: 1.0378 - accuracy: 0.6440 - val_loss: 1.1559 - val_accuracy: 0.5898
# Epoch 7/10
# 391/391 [==============================] - 522s 1s/step - loss: 1.0087 - accuracy: 0.6540 - val_loss: 1.5316 - val_accuracy: 0.4986
# Epoch 8/10
# 391/391 [==============================] - 530s 1s/step - loss: 0.9105 - accuracy: 0.6899 - val_loss: 1.2035 - val_accuracy: 0.6006
# Epoch 9/10
# 391/391 [==============================] - 523s 1s/step - loss: 0.8302 - accuracy: 0.7154 - val_loss: 1.1819 - val_accuracy: 0.6104
# Epoch 10/10
# 391/391 [==============================] - 518s 1s/step - loss: 0.7997 - accuracy: 0.7280 - val_loss: 1.1035 - val_accuracy: 0.6365

# %%
import os

# dosya yolu
file_path = "../input/testing/horse.jpg"

# dosyanın mevcut olup olmadığını kontrol et
if os.path.exists(file_path):
    print("Dosya mevcut")
else:
    print("Dosya mevcut değil")
# Out:
# Dosya mevcut

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing import image
from PIL import Image

# load model
model = tf.keras.models.load_model('my_model.h5')

# for kaggle file path
file_path = "../input/image-testing/dog7.jpg"

# load img
img = Image.open(file_path)

# resize img
img = img.resize((32, 32))

# convert to nummpy
img_array = np.asarray(img)

# change array size
img_array = np.expand_dims(img_array, axis=0)

# tahmini yap
prediction = model.predict(img_array)
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
predicted_class = class_names[np.argmax(prediction)]

print("Predicted class: ", predicted_class)
# Out:
# 1/1 [==============================] - 0s 189ms/step
# Predicted class:  dog
